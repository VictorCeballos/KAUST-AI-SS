# %% [markdown]
# This notebook has been inspired from [REINFORCE-CartPole](https://colab.research.google.com/github/goodboychan/goodboychan.github.io/blob/main/_notebooks/2021-05-12-REINFORCE-CartPole.ipynb#scrollTo=V4fcuCO2v-wf) and [goodboychan.github.io](https://github.com/goodboychan/goodboychan.github.io/tree/main) by Chanseok Kang [Policy Graidient](https://colab.research.google.com/github/huggingface/deep-rl-class/blob/master/notebooks/unit4/unit4.ipynb) by Thomas Simonini.

# %% [markdown]
# # REINFORCE

# %% [markdown]
# In this notebook, we will implement REINFORCE algorithm for Cart Pole Environment.

# %% [markdown]
# ## Cartpole

# %% [markdown]
# As the image below shows, the goal of the agent is to balance a verticle rod on the top of the car. This position is unstable and that is the main reason for the difficulty.
#
# ![Cartpole](https://gymnasium.farama.org/_images/cart_pole.gif)
#
# The problem is solved if the average of the agent's scores is greater than 195 gathered in 100 episodes.
# The agent receives reward 1 in each timestep until the psoition of the rod is correct (not inclined too far away from the vertical position).
#
# The episode ends if any one of the following occurs:
# - Pole Angle is greater than ±12°
# - Cart Position is greater than ±2.4 (center of the cart reaches the edge of the display)
# - Episode length is greater than 500 (200 for v0)
#
# The state is low dimensional and consists of:
# * position
# * velocity
# * angle
# * angular velocity
#
# You can read more the cartpole environment [here](https://gymnasium.farama.org/environments/classic_control/cart_pole/)

# %% [markdown]
# ## REINFORCE

# %% [markdown]
# REINFORCE is an elegant algorithm for maximizing the expected return. We sample a trajectory $\tau$ . If we get a high reward, we try to make it more likely. If we get a low reward, we try to make it less likely.
#
# We just need a policy that maximizes the expected return and we can do this by Gradient Ascent on Policy parameters.
#
# ![pg_pseudocode.png](data:image/png;base64,...)
#
#
# [Image Source](https://colab.research.google.com/github/huggingface/deep-rl-class/blob/master/notebooks/unit4/unit4.ipynb)

# %%
import gym
import math
import random
import numpy as np
import matplotlib
import matplotlib.pyplot as plt
from collections import deque

import torch
import torch.nn as nn
import torch.optim as optim
import torch.nn.functional as F
import torchvision.transforms as T
from torch.distributions import Categorical

# %%
# if gpu is to be used
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
# Out:
# /usr/local/lib/python3.10/dist-packages/ipykernel/ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)

# %%
# Create the environment
env = gym.make("CartPole-v1")
# Out:
# /usr/local/lib/python3.10/dist-packages/gym/core.py:317: DeprecationWarning: WARN: Initializing wrapper in old step API which returns one bool instead of two. It is recommended to set `new_step_api=True` to use new step API. This will be the default behaviour in future.
#   deprecation(
# /usr/local/lib/python3.10/dist-packages/gym/wrappers/step_api_compatibility.py:39: DeprecationWarning: WARN: Initializing environment in old step API which returns one bool instead of two. It is recommended to set `new_step_api=True` to use new step API. This will be the default behaviour in future.
#   deprecation(

# %% [markdown]
# ### Policy Network

# %%
# A neural network for policy
# It takes the state as input and predicts the probability of each action
class Policy(nn.Module):
    def __init__(self, n_observations, n_actions):
        super(Policy, self).__init__()
        #To Do: Define the structure of your network

    def forward(self, x):
        #To Do: Define the forward pass of the network.

    def act(self, state):
        state = torch.from_numpy(state).float().unsqueeze(0).to(device)
        probs = self.forward(state).cpu()
        m = Categorical(probs)
        action = m.sample()
        return action.item(), m.log_prob(action)

# %% [markdown]
# ### Hyperparameters

# %%
# Here, we will specify the hyperparameters

total_episodes = 500        # Total training episodes
max_steps = 200              # Max steps per episode
learning_rate = #To DO: please specify the learning rate
gamma = 0.99                 # Discounting rate

# %% [markdown]
# ### Training

# %%
print('observation space:', env.observation_space)
print('action space:', env.action_space)

state_size = env.observation_space.shape[0]
action_size = env.action_space.n
print('state size:', state_size)
print('action size:', action_size)
# Out:
# observation space: Box([-4.8000002e+00 -3.4028235e+38 -4.1887903e-01 -3.4028235e+38], [4.8000002e+00 3.4028235e+38 4.1887903e-01 3.4028235e+38], (4,), float32)
# action space: Discrete(2)
# state size: 4
# action size: 2

# %%
# Intialize policy network
policy_net = Policy(state_size, action_size).to(device)

# set up the optimizer
optimizer = optim.Adam(policy_net.parameters(), lr=learning_rate)

# %%
scores = []
for episode in range(1, total_episodes+1):
  saved_log_probs = []
  rewards = []
  state = env.reset()
  # collect trajectory
  for t in range(max_steps):
    # To Do: sample action and its log probability from policy

    # To Do: save the log probability for later use

    state, reward, done, _ = env.step(action)
    rewards.append(reward)
    if done:
        break

  scores.append(sum(rewards))

  # Compute the discounted returns at each timestep
  returns = deque(maxlen=max_steps)
  n_steps = len(rewards)
  # We will use the dynamic programming approach to reduce complexity of this operation.
  # We calculate from last to first and avoid redundant computations that would be needed
  # if we were to do it from first to last.

  for t in range(n_steps)[::-1]:
    disc_return_t = (returns[0] if len(returns)>0 else 0)
    returns.appendleft( gamma*disc_return_t + rewards[t]   )

  ## standardization of the returns is employed to make training more stable
  eps = np.finfo(np.float32).eps.item()
  ## eps is the smallest representable float, which is
  # added to the standard deviation of the returns to avoid numerical instabilities
  returns = torch.tensor(returns)
  returns = (returns - returns.mean()) / (returns.std() + eps)

  # Calculating policy loss:
  policy_loss = []
  for log_prob, disc_return in zip(saved_log_probs, returns):
       # To Do: Calculate the policy loss please note that we are using Gradient Ascent, not Descent. So we need to calculate it with negative rewards.

  policy_loss = torch.cat(policy_loss).sum()

  # Back propagation
  optimizer.zero_grad()
  policy_loss.backward()
  optimizer.step()

  print(f"Episode {episode}: Reward = {scores[-1]}")
# Out:
# Episode 1: Reward = 48.0
# Episode 2: Reward = 12.0
# Episode 3: Reward = 16.0
# Episode 4: Reward = 22.0
# Episode 5: Reward = 9.0
# Episode 6: Reward = 19.0
# Episode 7: Reward = 13.0
# Episode 8: Reward = 38.0
# Episode 9: Reward = 14.0
# Episode 10: Reward = 23.0
# Episode 11: Reward = 16.0
# Episode 12: Reward = 24.0
# Episode 13: Reward = 13.0
# Episode 14: Reward = 28.0
# Episode 15: Reward = 18.0
# Episode 16: Reward = 19.0
# Episode 17: Reward = 16.0
# Episode 18: Reward = 15.0
# Episode 19: Reward = 22.0
# Episode 20: Reward = 23.0
# Episode 21: Reward = 25.0
# Episode 22: Reward = 48.0
# Episode 23: Reward = 24.0
# Episode 24: Reward = 10.0
# Episode 25: Reward = 29.0
# Episode 26: Reward = 16.0
# Episode 27: Reward = 29.0
# Episode 28: Reward = 35.0
# Episode 29: Reward = 35.0
# Episode 30: Reward = 11.0
# Episode 31: Reward = 13.0
# Episode 32: Reward = 26.0
# Episode 33: Reward = 13.0
# Episode 34: Reward = 24.0
# Episode 35: Reward = 13.0
# Episode 36: Reward = 22.0
# Episode 37: Reward = 52.0
# Episode 38: Reward = 24.0
# Episode 39: Reward = 15.0
# Episode 40: Reward = 14.0
# Episode 41: Reward = 10.0
# Episode 42: Reward = 35.0
# Episode 43: Reward = 23.0
# Episode 44: Reward = 27.0
# Episode 45: Reward = 33.0
# Episode 46: Reward = 45.0
# Episode 47: Reward = 12.0
# Episode 48: Reward = 26.0
# Episode 49: Reward = 24.0
# Episode 50: Reward = 19.0
# Episode 51: Reward = 53.0
# Episode 52: Reward = 20.0
# Episode 53: Reward = 13.0
# Episode 54: Reward = 29.0
# Episode 55: Reward = 45.0
# Episode 56: Reward = 25.0
# Episode 57: Reward = 26.0
# Episode 58: Reward = 31.0
# Episode 59: Reward = 31.0
# Episode 60: Reward = 15.0
# Episode 61: Reward = 40.0
# Episode 62: Reward = 15.0
# Episode 63: Reward = 10.0
# Episode 64: Reward = 13.0
# Episode 65: Reward = 55.0
# Episode 66: Reward = 26.0
# Episode 67: Reward = 19.0
# Episode 68: Reward = 21.0
# Episode 69: Reward = 35.0
# Episode 70: Reward = 14.0
# Episode 71: Reward = 31.0
# Episode 72: Reward = 76.0
# Episode 73: Reward = 16.0
# Episode 74: Reward = 21.0
# Episode 75: Reward = 48.0
# Episode 76: Reward = 11.0
# Episode 77: Reward = 17.0
# Episode 78: Reward = 26.0
# Episode 79: Reward = 31.0
# Episode 80: Reward = 57.0
# Episode 81: Reward = 34.0
# Episode 82: Reward = 36.0
# Episode 83: Reward = 18.0
# Episode 84: Reward = 29.0
# Episode 85: Reward = 21.0
# Episode 86: Reward = 21.0
# Episode 87: Reward = 12.0
# Episode 88: Reward = 36.0
# Episode 89: Reward = 34.0
# Episode 90: Reward = 29.0
# Episode 91: Reward = 21.0
# Episode 92: Reward = 33.0
# Episode 93: Reward = 29.0
# Episode 94: Reward = 40.0
# Episode 95: Reward = 22.0
# Episode 96: Reward = 20.0
# Episode 97: Reward = 30.0
# Episode 98: Reward = 27.0
# Episode 99: Reward = 52.0
# Episode 100: Reward = 42.0
# Episode 101: Reward = 68.0
# Episode 102: Reward = 51.0
# Episode 103: Reward = 70.0
# Episode 104: Reward = 82.0
# Episode 105: Reward = 20.0
# Episode 106: Reward = 28.0
# Episode 107: Reward = 45.0
# Episode 108: Reward = 57.0
# Episode 109: Reward = 41.0
# Episode 110: Reward = 38.0
# Episode 111: Reward = 74.0
# Episode 112: Reward = 83.0
# Episode 113: Reward = 11.0
# Episode 114: Reward = 23.0
# Episode 115: Reward = 33.0
# Episode 116: Reward = 26.0
# Episode 117: Reward = 21.0
# Episode 118: Reward = 41.0
# Episode 119: Reward = 37.0
# Episode 120: Reward = 22.0
# Episode 121: Reward = 29.0
# Episode 122: Reward = 14.0
# Episode 123: Reward = 87.0
# Episode 124: Reward = 20.0
# Episode 125: Reward = 43.0
# Episode 126: Reward = 53.0
# Episode 127: Reward = 46.0
# Episode 128: Reward = 46.0
# Episode 129: Reward = 36.0
# Episode 130: Reward = 58.0
# Episode 131: Reward = 70.0
# Episode 132: Reward = 43.0
# Episode 133: Reward = 73.0
# Episode 134: Reward = 31.0
# Episode 135: Reward = 43.0
# Episode 136: Reward = 140.0
# Episode 137: Reward = 44.0
# Episode 138: Reward = 73.0
# Episode 139: Reward = 85.0
# Episode 140: Reward = 76.0
# Episode 141: Reward = 50.0
# Episode 142: Reward = 48.0
# Episode 143: Reward = 52.0
# Episode 144: Reward = 64.0
# Episode 145: Reward = 32.0
# Episode 146: Reward = 29.0
# Episode 147: Reward = 42.0
# Episode 148: Reward = 72.0
# Episode 149: Reward = 31.0
# Episode 150: Reward = 48.0
# Episode 151: Reward = 27.0
# Episode 152: Reward = 76.0
# Episode 153: Reward = 38.0
# Episode 154: Reward = 34.0
# Episode 155: Reward = 114.0
# Episode 156: Reward = 47.0
# Episode 157: Reward = 88.0
# Episode 158: Reward = 56.0
# Episode 159: Reward = 57.0
# Episode 160: Reward = 50.0
# Episode 161: Reward = 44.0
# Episode 162: Reward = 81.0
# Episode 163: Reward = 29.0
# Episode 164: Reward = 99.0
# Episode 165: Reward = 14.0
# Episode 166: Reward = 45.0
# Episode 167: Reward = 70.0
# Episode 168: Reward = 35.0
# Episode 169: Reward = 34.0
# Episode 170: Reward = 73.0
# Episode 171: Reward = 52.0
# Episode 172: Reward = 42.0
# Episode 173: Reward = 154.0
# Episode 174: Reward = 65.0
# Episode 175: Reward = 58.0
# Episode 176: Reward = 72.0
# Episode 177: Reward = 80.0
# Episode 178: Reward = 56.0
# Episode 179: Reward = 45.0
# Episode 180: Reward = 33.0
# Episode 181: Reward = 40.0
# Episode 182: Reward = 75.0
# Episode 183: Reward = 104.0
# Episode 184: Reward = 42.0
# Episode 185: Reward = 43.0
# Episode 186: Reward = 56.0
# Episode 187: Reward = 64.0
# Episode 188: Reward = 46.0
# Episode 189: Reward = 33.0
# Episode 190: Reward = 68.0
# Episode 191: Reward = 66.0
# Episode 192: Reward = 94.0
# Episode 193: Reward = 87.0
# Episode 194: Reward = 48.0
# Episode 195: Reward = 77.0
# Episode 196: Reward = 46.0
# Episode 197: Reward = 30.0
# Episode 198: Reward = 40.0
# Episode 199: Reward = 105.0
# Episode 200: Reward = 60.0
# Episode 201: Reward = 93.0
# Episode 202: Reward = 35.0
# Episode 203: Reward = 86.0
# Episode 204: Reward = 77.0
# Episode 205: Reward = 40.0
# Episode 206: Reward = 123.0
# Episode 207: Reward = 33.0
# Episode 208: Reward = 73.0
# Episode 209: Reward = 38.0
# Episode 210: Reward = 39.0
# Episode 211: Reward = 43.0
# Episode 212: Reward = 172.0
# Episode 213: Reward = 40.0
# Episode 214: Reward = 39.0
# Episode 215: Reward = 48.0
# Episode 216: Reward = 99.0
# Episode 217: Reward = 77.0
# Episode 218: Reward = 135.0
# Episode 219: Reward = 58.0
# Episode 220: Reward = 135.0
# Episode 221: Reward = 24.0
# Episode 222: Reward = 57.0
# Episode 223: Reward = 60.0
# Episode 224: Reward = 83.0
# Episode 225: Reward = 64.0
# Episode 226: Reward = 42.0
# Episode 227: Reward = 76.0
# Episode 228: Reward = 33.0
# Episode 229: Reward = 49.0
# Episode 230: Reward = 45.0
# Episode 231: Reward = 21.0
# Episode 232: Reward = 68.0
# Episode 233: Reward = 38.0
# Episode 234: Reward = 73.0
# Episode 235: Reward = 53.0
# Episode 236: Reward = 35.0
# Episode 237: Reward = 57.0
# Episode 238: Reward = 68.0
# Episode 239: Reward = 54.0
# Episode 240: Reward = 70.0
# Episode 241: Reward = 44.0
# Episode 242: Reward = 97.0
# Episode 243: Reward = 96.0
# Episode 244: Reward = 54.0
# Episode 245: Reward = 72.0
# Episode 246: Reward = 62.0
# Episode 247: Reward = 63.0
# Episode 248: Reward = 89.0
# Episode 249: Reward = 77.0
# Episode 250: Reward = 66.0
# Episode 251: Reward = 48.0
# Episode 252: Reward = 119.0
# Episode 253: Reward = 87.0
# Episode 254: Reward = 63.0
# Episode 255: Reward = 37.0
# Episode 256: Reward = 90.0
# Episode 257: Reward = 66.0
# Episode 258: Reward = 128.0
# Episode 259: Reward = 97.0
# Episode 260: Reward = 86.0
# Episode 261: Reward = 62.0
# Episode 262: Reward = 48.0
# Episode 263: Reward = 51.0
# Episode 264: Reward = 98.0
# Episode 265: Reward = 44.0
# Episode 266: Reward = 92.0
# Episode 267: Reward = 62.0
# Episode 268: Reward = 84.0
# Episode 269: Reward = 53.0
# Episode 270: Reward = 74.0
# Episode 271: Reward = 123.0
# Episode 272: Reward = 84.0
# Episode 273: Reward = 62.0
# Episode 274: Reward = 17.0
# Episode 275: Reward = 58.0
# Episode 276: Reward = 33.0
# Episode 277: Reward = 70.0
# Episode 278: Reward = 70.0
# Episode 279: Reward = 22.0
# Episode 280: Reward = 80.0
# Episode 281: Reward = 91.0
# Episode 282: Reward = 24.0
# Episode 283: Reward = 43.0
# Episode 284: Reward = 55.0
# Episode 285: Reward = 73.0
# Episode 286: Reward = 83.0
# Episode 287: Reward = 45.0
# Episode 288: Reward = 97.0
# Episode 289: Reward = 114.0
# Episode 290: Reward = 111.0
# Episode 291: Reward = 108.0
# Episode 292: Reward = 92.0
# Episode 293: Reward = 120.0
# Episode 294: Reward = 115.0
# Episode 295: Reward = 30.0
# Episode 296: Reward = 111.0
# Episode 297: Reward = 139.0
# Episode 298: Reward = 97.0
# Episode 299: Reward = 94.0
# Episode 300: Reward = 105.0
# Episode 301: Reward = 121.0
# Episode 302: Reward = 49.0
# Episode 303: Reward = 155.0
# Episode 304: Reward = 32.0
# Episode 305: Reward = 97.0
# Episode 306: Reward = 97.0
# Episode 307: Reward = 116.0
# Episode 308: Reward = 72.0
# Episode 309: Reward = 114.0
# Episode 310: Reward = 74.0
# Episode 311: Reward = 133.0
# Episode 312: Reward = 78.0
# Episode 313: Reward = 25.0
# Episode 314: Reward = 123.0
# Episode 315: Reward = 78.0
# Episode 316: Reward = 163.0
# Episode 317: Reward = 37.0
# Episode 318: Reward = 51.0
# Episode 319: Reward = 105.0
# Episode 320: Reward = 139.0
# Episode 321: Reward = 117.0
# Episode 322: Reward = 73.0
# Episode 323: Reward = 61.0
# Episode 324: Reward = 116.0
# Episode 325: Reward = 132.0
# Episode 326: Reward = 139.0
# Episode 327: Reward = 82.0
# Episode 328: Reward = 96.0
# Episode 329: Reward = 115.0
# Episode 330: Reward = 118.0
# Episode 331: Reward = 177.0
# Episode 332: Reward = 154.0
# Episode 333: Reward = 63.0
# Episode 334: Reward = 107.0
# Episode 335: Reward = 75.0
# Episode 336: Reward = 155.0
# Episode 337: Reward = 99.0
# Episode 338: Reward = 127.0
# Episode 339: Reward = 64.0
# Episode 340: Reward = 200.0
# Episode 341: Reward = 135.0
# Episode 342: Reward = 200.0
# Episode 343: Reward = 165.0
# Episode 344: Reward = 68.0
# Episode 345: Reward = 118.0
# Episode 346: Reward = 104.0
# Episode 347: Reward = 62.0
# Episode 348: Reward = 102.0
# Episode 349: Reward = 139.0
# Episode 350: Reward = 163.0
# Episode 351: Reward = 185.0
# Episode 352: Reward = 200.0
# Episode 353: Reward = 18.0
# Episode 354: Reward = 177.0
# Episode 355: Reward = 179.0
# Episode 356: Reward = 198.0
# Episode 357: Reward = 200.0
# Episode 358: Reward = 166.0
# Episode 359: Reward = 200.0
# Episode 360: Reward = 160.0
# Episode 361: Reward = 158.0
# Episode 362: Reward = 129.0
# Episode 363: Reward = 188.0
# Episode 364: Reward = 136.0
# Episode 365: Reward = 191.0
# Episode 366: Reward = 140.0
# Episode 367: Reward = 200.0
# Episode 368: Reward = 115.0
# Episode 369: Reward = 200.0
# Episode 370: Reward = 152.0
# Episode 371: Reward = 199.0
# Episode 372: Reward = 181.0
# Episode 373: Reward = 192.0
# Episode 374: Reward = 29.0
# Episode 375: Reward = 143.0
# Episode 376: Reward = 89.0
# Episode 377: Reward = 166.0
# Episode 378: Reward = 116.0
# Episode 379: Reward = 148.0
# Episode 380: Reward = 155.0
# Episode 381: Reward = 200.0
# Episode 382: Reward = 137.0
# Episode 383: Reward = 110.0
# Episode 384: Reward = 115.0
# Episode 385: Reward = 144.0
# Episode 386: Reward = 119.0
# Episode 387: Reward = 194.0
# Episode 388: Reward = 200.0
# Episode 389: Reward = 38.0
# Episode 390: Reward = 150.0
# Episode 391: Reward = 149.0
# Episode 392: Reward = 179.0
# Episode 393: Reward = 200.0
# Episode 394: Reward = 52.0
# Episode 395: Reward = 164.0
# Episode 396: Reward = 120.0
# Episode 397: Reward = 121.0
# Episode 398: Reward = 125.0
# Episode 399: Reward = 163.0
# Episode 400: Reward = 200.0
# Episode 401: Reward = 139.0
# Episode 402: Reward = 126.0
# Episode 403: Reward = 156.0
# Episode 404: Reward = 58.0
# Episode 405: Reward = 97.0
# Episode 406: Reward = 200.0
# Episode 407: Reward = 200.0
# Episode 408: Reward = 88.0
# Episode 409: Reward = 200.0
# Episode 410: Reward = 117.0
# Episode 411: Reward = 200.0
# Episode 412: Reward = 64.0
# Episode 413: Reward = 200.0
# Episode 414: Reward = 112.0
# Episode 415: Reward = 127.0
# Episode 416: Reward = 119.0
# Episode 417: Reward = 115.0
# Episode 418: Reward = 84.0
# Episode 419: Reward = 192.0
# Episode 420: Reward = 200.0
# Episode 421: Reward = 135.0
# Episode 422: Reward = 113.0
# Episode 423: Reward = 200.0
# Episode 424: Reward = 137.0
# Episode 425: Reward = 122.0
# Episode 426: Reward = 135.0
# Episode 427: Reward = 121.0
# Episode 428: Reward = 148.0
# Episode 429: Reward = 200.0
# Episode 430: Reward = 112.0
# Episode 431: Reward = 184.0
# Episode 432: Reward = 181.0
# Episode 433: Reward = 200.0
# Episode 434: Reward = 200.0
# Episode 435: Reward = 165.0
# Episode 436: Reward = 173.0
# Episode 437: Reward = 58.0
# Episode 438: Reward = 138.0
# Episode 439: Reward = 176.0
# Episode 440: Reward = 121.0
# Episode 441: Reward = 73.0
# Episode 442: Reward = 158.0
# Episode 443: Reward = 200.0
# Episode 444: Reward = 200.0
# Episode 445: Reward = 103.0
# Episode 446: Reward = 130.0
# Episode 447: Reward = 110.0
# Episode 448: Reward = 195.0
# Episode 449: Reward = 176.0
# Episode 450: Reward = 200.0
# Episode 451: Reward = 147.0
# Episode 452: Reward = 192.0
# Episode 453: Reward = 177.0
# Episode 454: Reward = 200.0
# Episode 455: Reward = 200.0
# Episode 456: Reward = 147.0
# Episode 457: Reward = 200.0
# Episode 458: Reward = 200.0
# Episode 459: Reward = 200.0
# Episode 460: Reward = 161.0
# Episode 461: Reward = 200.0
# Episode 462: Reward = 200.0
# Episode 463: Reward = 163.0
# Episode 464: Reward = 200.0
# Episode 465: Reward = 200.0
# Episode 466: Reward = 200.0
# Episode 467: Reward = 164.0
# Episode 468: Reward = 128.0
# Episode 469: Reward = 200.0
# Episode 470: Reward = 146.0
# Episode 471: Reward = 134.0
# Episode 472: Reward = 129.0
# Episode 473: Reward = 190.0
# Episode 474: Reward = 200.0
# Episode 475: Reward = 135.0
# Episode 476: Reward = 200.0
# Episode 477: Reward = 190.0
# Episode 478: Reward = 200.0
# Episode 479: Reward = 112.0
# Episode 480: Reward = 200.0
# Episode 481: Reward = 148.0
# Episode 482: Reward = 200.0
# Episode 483: Reward = 126.0
# Episode 484: Reward = 200.0
# Episode 485: Reward = 139.0
# Episode 486: Reward = 138.0
# Episode 487: Reward = 150.0
# Episode 488: Reward = 101.0
# Episode 489: Reward = 171.0
# Episode 490: Reward = 161.0
# Episode 491: Reward = 197.0
# Episode 492: Reward = 152.0
# Episode 493: Reward = 169.0
# Episode 494: Reward = 200.0
# Episode 495: Reward = 200.0
# Episode 496: Reward = 143.0
# Episode 497: Reward = 170.0
# Episode 498: Reward = 176.0
# Episode 499: Reward = 152.0
# Episode 500: Reward = 200.0

# %%
plt.figure(figsize=(16,4))
plt.plot(scores)
plt.xlabel("Episodes")
plt.ylabel("Reward")
# Out:
# Text(0, 0.5, 'Reward')

# %% [markdown]
# ### Visualization

# %%
# For visualization
from gym.wrappers.monitoring import video_recorder
from IPython.display import HTML
from IPython import display
import glob
import base64, io, os

os.environ['SDL_VIDEODRIVER']='dummy'

# %%
os.makedirs("video", exist_ok=True)

def show_video(env_name):
    mp4list = glob.glob('video/*.mp4')
    if len(mp4list) > 0:
        mp4 = 'video/{}.mp4'.format(env_name)
        video = io.open(mp4, 'r+b').read()
        encoded = base64.b64encode(video)
        display.display(HTML(data='''<video alt="test" autoplay
                loop controls style="height: 400px;">
                <source src="data:video/mp4;base64,{0}" type="video/mp4" />
             </video>'''.format(encoded.decode('ascii'))))
    else:
        print("Could not find video")

def show_video_of_model(env_name):
    vid = video_recorder.VideoRecorder(env, path="video/{}.mp4".format(env_name))
    state = env.reset()
    done = False
    for t in range(max_steps):
        vid.capture_frame()
        action, _ = policy_net.act(state)
        next_state, reward, done, info = env.step(action)
        # print(f"state: {state}, action: {action.item()}",next_state, reward, done)
        state = next_state
        if done:
            break
    vid.close()
    env.close()

# %%
show_video_of_model("CartPole-v1")
# Out:
# /usr/local/lib/python3.10/dist-packages/gym/wrappers/monitoring/video_recorder.py:78: DeprecationWarning: WARN: Recording ability for environment CartPole-v1 initialized with `render_mode=None` is marked as deprecated and will be removed in the future.
#   logger.deprecation(
# /usr/local/lib/python3.10/dist-packages/gym/wrappers/monitoring/video_recorder.py:101: DeprecationWarning: WARN: <class 'gym.wrappers.monitoring.video_recorder.VideoRecorder'> is marked as deprecated and will be removed in the future.
#   logger.deprecation(
# /usr/local/lib/python3.10/dist-packages/gym/core.py:43: DeprecationWarning: WARN: The argument mode in render method is deprecated; use render_mode during environment initialization instead.
# See here for more information: https://www.gymlibrary.ml/content/api/
#   deprecation(
# /usr/local/lib/python3.10/dist-packages/gym/core.py:43: DeprecationWarning: WARN: The argument mode in render method is deprecated; use render_mode during environment initialization instead.
# See here for more information: https://www.gymlibrary.ml/content/api/
#   deprecation(

# %%
show_video("CartPole-v1")
# Out:
# /usr/local/lib/python3.10/dist-packages/ipykernel/ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)
# <video alt="test" autoplay
#                 loop controls style="height: 400px;">
#                 <source src="data:video/mp4;base64,..." type="video/mp4" />
#              </video>
