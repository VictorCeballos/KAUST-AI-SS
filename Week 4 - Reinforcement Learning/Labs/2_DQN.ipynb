# %% [markdown]
# This notebook has been inspired from [REINFORCEMENT LEARNING (DQN) TUTORIAL](https://pytorch.org/tutorials/intermediate/reinforcement_q_learning.html) and [reinforcement_q_learning](https://colab.research.google.com/github/pytorch/tutorials/blob/gh-pages/_downloads/reinforcement_q_learning.ipynb#scrollTo=ChfTgUJGcvEA) by Paszke & Towers.

# %% [markdown]
# # Deep Q-Learning

# %% [markdown]
# In this notebook, we will implement Deep Q-Learning Reinforcement learning algorithm for Cart Pole Environment.

# %% [markdown]
# ## Cartpole

# %% [markdown]
# As the image below shows, the goal of the agent is to balance a verticle rod on the top of the car. This position is unstable and that is the main reason for the difficulty.
#
# ![Cartpole](https://gymnasium.farama.org/_images/cart_pole.gif)
#
# The problem is solved if the average of the agent's scores is greater than 195 gathered in 100 episodes.
# The agent receives reward 1 in each timestep until the psoition of the rod is correct (not inclined too far away from the vertical position).
#
# The episode ends if any one of the following occurs:
# - Pole Angle is greater than ±12°
# - Cart Position is greater than ±2.4 (center of the cart reaches the edge of the display)
# - Episode length is greater than 500 (200 for v0)
#
# The state is low dimensional and cosists of:
# * position
# * velocity
# * angle
# * angular velocity
#
# You can read more the cartpole environment [here](https://gymnasium.farama.org/environments/classic_control/cart_pole/)

# %% [markdown]
# ## Deep Q-Learning

# %% [markdown]
# The main idea behind Q-learning is that if we had a function
# $Q^*: State \times Action \rightarrow \mathbb{R}$, that could tell
# us what our return would be, if we were to take an action in a given
# state, then we could easily construct a policy that maximizes our
# rewards:
#
# \begin{align}\pi^*(s) = \arg\!\max_a \ Q^*(s, a)\end{align}
#
# But this is not scalable. Must compute $Q(s,a)$ for every state-action pair. If state is e.g. current game state pixels, computationally infeasible to compute for entire state space! But, since neural networks are universal function
# approximators, we can simply create one and train it to resemble
# $Q^*$.
#
# For our training update rule, we'll use a fact that every $Q$
# function for some policy obeys the Bellman equation:
#
# \begin{align}Q^{\pi}(s, a) = r + \gamma Q^{\pi}(s', \pi(s'))\end{align}
#
# The difference between the two sides of the equality is known as the
# temporal difference error, $\delta$:
#
# \begin{align}\delta = Q(s, a) - (r + \gamma \max_a Q(s', a))\end{align}
#
# To minimise this error, we will use the `Huber
# loss <https://en.wikipedia.org/wiki/Huber_loss>`__. The Huber loss acts
# like the mean squared error when the error is small, but like the mean
# absolute error when the error is large - this makes it more robust to
# outliers when the estimates of $Q$ are very noisy. We calculate
# this over a batch of transitions, $B$, sampled from the replay
# memory:
#
# \begin{align}\mathcal{L} = \frac{1}{|B|}\sum_{(s, a, s', r) \ \in \ B} \mathcal{L}(\delta)\end{align}
#
# \begin{align}\text{where} \quad \mathcal{L}(\delta) = \begin{cases}
#      \frac{1}{2}{\delta^2}  & \text{for } |\delta| \le 1, \\
#      |\delta| - \frac{1}{2} & \text{otherwise.}
#    \end{cases}\end{align}

# %% [markdown]
# ![dqn_target.png](data:image/png;base64,...)

# %%
import gym
import math
import random
import numpy as np
import matplotlib
import matplotlib.pyplot as plt
from collections import namedtuple
from itertools import count
from PIL import Image

import torch
import torch.nn as nn
import torch.optim as optim
import torch.nn.functional as F
import torchvision.transforms as T

# %%
# if gpu is to be used
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
device
# Out:
# device(type='cuda')

# %%
# Create the environment
env = gym.make("CartPole-v1")
# Out:
# /usr/local/lib/python3.10/dist-packages/gym/core.py:317: DeprecationWarning: WARN: Initializing wrapper in old step API which returns one bool instead of two. It is recommended to set `new_step_api=True` to use new step API. This will be the default behaviour in future.
#   deprecation(
# /usr/local/lib/python3.10/dist-packages/gym/wrappers/step_api_compatibility.py:39: DeprecationWarning: WARN: Initializing environment in old step API which returns one bool instead of two. It is recommended to set `new_step_api=True` to use new step API. This will be the default behaviour in future.
#   deprecation(

# %% [markdown]
# ### Experience Replay

# %% [markdown]
# Learning from batches of consecutive samples is problematic as the sample are correlated and it can create a bad feedback loop if one action is dominated in the samples.
#
# We can address these problems using an experience replay memory. It maintains a record for all the transitions experienced. The agent is then trained by sampling random minibatches from the replay memory.

# %%
# Named tuple representing a single transition in our environment
Transition = namedtuple('Transition',
                        ('state', 'action', 'next_state', 'reward', 'done'))

# Cyclic buffer of bounded size that holds and samples the transitions observed recently
class ReplayMemory(object):
    def __init__(self, capacity):
        self.capacity = capacity
        self.memory = []
        self.position = 0

    def push(self, *args):
        """Saves a transition."""
        if len(self.memory) < self.capacity:
            self.memory.append(None)
        self.memory[self.position] = Transition(*args)
        self.position = (self.position + 1) % self.capacity

    def sample(self, batch_size):
        return random.sample(self.memory, batch_size)

    def __len__(self):
        return len(self.memory)

# %% [markdown]
# ### Q-Network

# %%
# A neural network approximater for Q-Value.
# It takes the state as input and predicts the Q-value for all actions at that state
class DQN(nn.Module):
    def __init__(self, n_observations, n_actions):
        super(DQN, self).__init__()
        #TODO: add 3 layers

    def forward(self, x):
        #TODO: compelte this, use relus, the last layer should be without activation

# %% [markdown]
# <details>
# <summary>Hint: Neural Network Approximator for Q-Value</summary>
#
# ```python
# # A neural network approximater for Q-Value.
# # It takes the state as input and predicts the Q-value for all actions at that state
# class DQN(nn.Module):
#     def __init__(self, n_observations, n_actions):
#         super(DQN, self).__init__()
#         self.layer1 = nn.Linear(n_observations, 128)
#         self.layer2 = nn.Linear(128, 128)
#         self.layer3 = nn.Linear(128, n_actions)
#
#     def forward(self, x):
#         x = F.relu(self.layer1(x))
#         x = F.relu(self.layer2(x))
#         return self.layer3(x)
# ```
# </details>

# %% [markdown]
# ### Exploration vs Exploitation

# %% [markdown]
# Notice that Q-learning only learns about the states and actions it visits. What if an optimal state remains unvisited due to not being explored. The agent should sometimes pick suboptimal actions in order to visit new states and actions. <br>
#
# A simple strategy is to use an $\epsilon$-greedy policy. According to this policy, the agent takes a random action with epsilon probability. The value of epsilon is high at the start of training and low towards the end. So, the agent explores more at the start and then exploit the learned policy more at the end.

# %% [markdown]
# ### Hyperparameters

# %%
# Here, we will specify the hyperparameters

total_episodes = 1000         # Total training episodes
max_steps = 200              # Max steps per episode
learning_rate = 1e-3         # Learning rate|
gamma = 0.99                 # Discounting rate
batch_size = 128             # Training Batch size
target_update = 5            # Target network update frequency
train_frquency = 1           # Train Q network every train_frquency episodes
train_epochs = 2             # Training epochs during each training cycle

# Exploration parameters
epsilon = 1.0                 # Exploration rate
max_epsilon = 1.0             # Exploration probability at start
min_epsilon = 0.01            # Minimum exploration probability
decay_rate = 0.003            # Exponential decay rate for exploration prob

# %% [markdown]
# ### Training

# %%
print('observation space:', env.observation_space)
print('action space:', env.action_space)

state_size = env.observation_space.shape[0]
action_size = env.action_space.n
print('state size:', state_size)
print('action size:', action_size)
# Out:
# observation space: Box([-4.8000002e+00 -3.4028235e+38 -4.1887903e-01 -3.4028235e+38], [4.8000002e+00 3.4028235e+38 4.1887903e-01 3.4028235e+38], (4,), float32)
# action space: Discrete(2)
# state size: 4
# action size: 2

# %%
# Intialize both Q-networks
policy_net = DQN(state_size, action_size).to(device)
target_net = DQN(state_size, action_size).to(device)

# update target network
target_net.load_state_dict(policy_net.state_dict())
target_net.eval()

# set up the optimizer
optimizer = optim.RMSprop(policy_net.parameters(), lr=learning_rate)

# Initialize the replay buffer
memory = ReplayMemory(10000)

# %% [markdown]
# <details>
# <summary>Solution</summary>
#
# ```python
#   exp_exp_tradeoff = random.uniform(0, 1)
# ```
# </details>

# %%
# get action for current state according to the greedy policy
def get_action(state):
  ## First we randomize a number
  exp_exp_tradeoff =  #TODO: Sample a random uniform distrubtion from 0,1
  ## If this number > greater than epsilon --> exploitation (taking the biggest Q value for this state)
  if exp_exp_tradeoff > epsilon:
    with torch.no_grad():
      action = policy_net(state).max(1)[1].view(1, 1)

  # Else doing a random choice --> exploration
  else:
    action = env.action_space.sample()
    action = torch.tensor([action], device=device).view(1, 1)
  return action

# %% [markdown]
# <details>
# <summary>Solution</summary>
#
# ```python
# # List of rewards
# rewards = []
#
# for episode in range(1, total_episodes+1):
#     # Initialize the environment and state
#     state = env.reset()
#     state = torch.tensor([state], device=device)
#     total_rewards = 0
#     for _ in range(max_steps):
#         # Select and perform an action
#         action = get_action(state)
#         next_state, reward, done, _ = env.step(action.item())
#
#         total_rewards += reward
#
#         reward = torch.tensor([reward], device=device)
#         done = torch.tensor([int(done)], device=device)
#         next_state = torch.tensor([next_state], device=device)
#
#         # Store the transition in memory
#         memory.push(state, action, next_state, reward, done)
#
#         # Move to the next state
#         state = next_state
#
#         if done:
#             break
#
#     # optimize the policy
#     if episode % train_frquency == 0 and len(memory) >= batch_size:
#       for _ in range(train_epochs):
#         # get samples from experience replay memory
#         transitions = memory.sample(batch_size)
#         # unroll and reroll to get them in proper format
#         batch = Transition(*zip(*transitions))
#
#         state_batch = torch.cat(batch.state)
#         action_batch = torch.cat(batch.action)
#         next_state_batch = torch.cat(batch.next_state)
#         reward_batch = torch.cat(batch.reward)
#         done_batch = torch.cat(batch.done)
#
#         # Compute Q(s_t, a) - the model computes Q(s_t), then we select the
#         # columns of actions taken
#         state_action_values = policy_net(state_batch).gather(1, action_batch)
#
#         # Compute V(s_{t+1}) for all next states and get the max q values.
#         with torch.no_grad():
#           next_state_values = target_net(next_state_batch).max(1)[0].detach()
#         # Compute the target Q values
#         target_q_values = (next_state_values * (1-done_batch) * gamma) + reward_batch
#
#         # Compute Huber loss
#         loss = F.smooth_l1_loss(state_action_values, target_q_values.unsqueeze(1))
#
#         # Optimize the model
#         optimizer.zero_grad()
#         loss.backward()
#         optimizer.step()
#
#
#     # Update the target network
#     if episode % target_update == 0:
#         target_net.load_state_dict(policy_net.state_dict())
#
#     # Reduce epsilon (because we need less and less exploration)
#     epsilon = min_epsilon + (max_epsilon - min_epsilon)*np.exp(-decay_rate*episode)
#     rewards.append(total_rewards)
#     print(f"Episode {episode}: Reward = {total_rewards}, Epsilon = {epsilon}")
# ```
# </details>

# %%
# List of rewards
rewards = []

for episode in range(1, total_episodes+1):
    # Initialize the environment and state
    state =  #TODO: Reset the enviorment
    state =  #TODO: Transfer into a tensor, hint: [state]
    total_rewards =  # TODO: Reset the rewards
    for _ in range(max_steps):
        # Select and perform an action
        action =  #TODO: get the next action
        next_state, reward, done, _ = env.step(action.item())

        total_rewards +=  #TODO: Accumulate the reward

        reward = torch.tensor([reward], device=device)
        done = torch.tensor([int(done)], device=device)
        next_state = torch.tensor([next_state], device=device)

        # Store the transition in memory
        memory.push(state, action, next_state, reward, done)

        # Move to the next state
        state = next_state

        if done:
            break

    # optimize the policy
    if episode % train_frquency == 0 and len(memory) >= batch_size:
      for _ in range(train_epochs):
        # get samples from experience replay memory
        transitions = memory.sample(batch_size)
        # unroll and reroll to get them in proper format
        batch = Transition(*zip(*transitions))

        state_batch = torch.cat(batch.state)
        action_batch = torch.cat(batch.action)
        next_state_batch = torch.cat(batch.next_state)
        reward_batch = torch.cat(batch.reward)
        done_batch = torch.cat(batch.done)

        # Compute Q(s_t, a) - the model computes Q(s_t), then we select the
        # columns of actions taken
        state_action_values = policy_net(state_batch).gather(1, action_batch)

        # Compute V(s_{t+1}) for all next states and get the max q values.
        with torch.no_grad():
          next_state_values = target_net(next_state_batch).max(1)[0].detach()
        # Compute the target Q values
        target_q_values = (next_state_values * (1-done_batch) * gamma) + reward_batch

        # Compute Huber loss
        loss = # TODO: Create the Huber loss

        # Optimize the model
        optimizer.zero_grad()
        loss.backward()
        optimizer.step()


    # Update the target network
    if episode % target_update == 0:
        target_net.load_state_dict(policy_net.state_dict())

    # Reduce epsilon (because we need less and less exploration)
    epsilon = min_epsilon + (max_epsilon - min_epsilon)*np.exp(-decay_rate*episode)
    rewards.append(total_rewards)
    print(f"Episode {episode}: Reward = {total_rewards}, Epsilon = {epsilon}")
# Out:
# <ipython-input-10-d9be5873d5e5>:7: UserWarning: Creating a tensor from a list of numpy.ndarrays is extremely slow. Please consider converting the list to a single numpy.ndarray with numpy.array() before converting to a tensor. (Triggered internally at ../torch/csrc/utils/tensor_new.cpp:274.)
#   state = torch.tensor([state], device=device) #TODO: Transfer into a tensor
# /usr/local/lib/python3.10/dist-packages/gym/utils/passive_env_checker.py:241: DeprecationWarning: `np.bool8` is a deprecated alias for `np.bool_`.  (Deprecated NumPy 1.24)
#   if not isinstance(terminated, (bool, np.bool8)):
# Episode 1: Reward = 16.0, Epsilon = 0.9970344505483394
# Episode 2: Reward = 27.0, Epsilon = 0.994077784413396
# Episode 3: Reward = 13.0, Epsilon = 0.9911299749851549
# Episode 4: Reward = 47.0, Epsilon = 0.9881909957333114
# Episode 5: Reward = 32.0, Epsilon = 0.9852608202070321
# Episode 6: Reward = 18.0, Epsilon = 0.9823394220347178
# Episode 7: Reward = 13.0, Epsilon = 0.9794267749237651
# Episode 8: Reward = 11.0, Epsilon = 0.9765228526603303
# Episode 9: Reward = 22.0, Epsilon = 0.9736276291090935
# Episode 10: Reward = 11.0, Epsilon = 0.9707410782130231
# Episode 11: Reward = 16.0, Epsilon = 0.9678631739931417
# Episode 12: Reward = 14.0, Epsilon = 0.9649938905482919
# Episode 13: Reward = 15.0, Epsilon = 0.962133202054903
# Episode 14: Reward = 22.0, Epsilon = 0.9592810827667598
# Episode 15: Reward = 15.0, Epsilon = 0.9564375070147689
# Episode 16: Reward = 23.0, Epsilon = 0.9536024492067297
# Episode 17: Reward = 14.0, Epsilon = 0.9507758838271027
# Episode 18: Reward = 16.0, Epsilon = 0.9479577854367803
# Episode 19: Reward = 19.0, Epsilon = 0.9451481286728581
# Episode 20: Reward = 45.0, Epsilon = 0.9423468882484062
# Episode 21: Reward = 12.0, Epsilon = 0.9395540389522419
# Episode 22: Reward = 17.0, Epsilon = 0.9367695556487027
# Episode 23: Reward = 19.0, Epsilon = 0.9339934132774199
# Episode 24: Reward = 22.0, Epsilon = 0.9312255868530936
# Episode 25: Reward = 14.0, Epsilon = 0.9284660514652673
# Episode 26: Reward = 22.0, Epsilon = 0.9257147822781039
# Episode 27: Reward = 19.0, Epsilon = 0.922971754530162
# Episode 28: Reward = 15.0, Epsilon = 0.9202369435341734
# Episode 29: Reward = 24.0, Epsilon = 0.9175103246768207
# Episode 30: Reward = 9.0, Epsilon = 0.9147918734185159
# Episode 31: Reward = 16.0, Epsilon = 0.9120815652931792
# Episode 32: Reward = 23.0, Epsilon = 0.9093793759080191
# Episode 33: Reward = 35.0, Epsilon = 0.906685280943313
# Episode 34: Reward = 25.0, Epsilon = 0.903999256152188
# Episode 35: Reward = 16.0, Epsilon = 0.9013212773604029
# Episode 36: Reward = 11.0, Epsilon = 0.8986513204661305
# Episode 37: Reward = 14.0, Epsilon = 0.8959893614397407
# Episode 38: Reward = 53.0, Epsilon = 0.8933353763235842
# Episode 39: Reward = 24.0, Epsilon = 0.8906893412317772
# Episode 40: Reward = 19.0, Epsilon = 0.888051232349986
# Episode 41: Reward = 19.0, Epsilon = 0.8854210259352127
# Episode 42: Reward = 21.0, Epsilon = 0.8827986983155819
# Episode 43: Reward = 65.0, Epsilon = 0.8801842258901273
# Episode 44: Reward = 16.0, Epsilon = 0.8775775851285796
# Episode 45: Reward = 12.0, Epsilon = 0.8749787525711541
# Episode 46: Reward = 18.0, Epsilon = 0.8723877048283404
# Episode 47: Reward = 19.0, Epsilon = 0.8698044185806911
# Episode 48: Reward = 13.0, Epsilon = 0.867228870578613
# Episode 49: Reward = 21.0, Epsilon = 0.8646610376421562
# Episode 50: Reward = 16.0, Epsilon = 0.8621008966608072
# Episode 51: Reward = 17.0, Epsilon = 0.8595484245932798
# Episode 52: Reward = 13.0, Epsilon = 0.8570035984673082
# Episode 53: Reward = 12.0, Epsilon = 0.8544663953794402
# Episode 54: Reward = 26.0, Epsilon = 0.8519367924948307
# Episode 55: Reward = 11.0, Epsilon = 0.8494147670470366
# Episode 56: Reward = 14.0, Epsilon = 0.846900296337812
# Episode 57: Reward = 22.0, Epsilon = 0.8443933577369037
# Episode 58: Reward = 21.0, Epsilon = 0.8418939286818471
# Episode 59: Reward = 13.0, Epsilon = 0.839401986677764
# Episode 60: Reward = 9.0, Epsilon = 0.8369175092971592
# Episode 61: Reward = 30.0, Epsilon = 0.83444047417972
# Episode 62: Reward = 42.0, Epsilon = 0.8319708590321133
# Episode 63: Reward = 51.0, Epsilon = 0.8295086416277863
# Episode 64: Reward = 25.0, Epsilon = 0.8270537998067656
# Episode 65: Reward = 14.0, Epsilon = 0.8246063114754583
# Episode 66: Reward = 20.0, Epsilon = 0.8221661546064527
# Episode 67: Reward = 15.0, Epsilon = 0.8197333072383208
# Episode 68: Reward = 14.0, Epsilon = 0.8173077474754197
# Episode 69: Reward = 33.0, Epsilon = 0.8148894534876953
# Episode 70: Reward = 37.0, Epsilon = 0.8124784035104852
# Episode 71: Reward = 48.0, Epsilon = 0.8100745758443235
# Episode 72: Reward = 22.0, Epsilon = 0.8076779488547449
# Episode 73: Reward = 18.0, Epsilon = 0.8052885009720903
# Episode 74: Reward = 30.0, Epsilon = 0.8029062106913125
# Episode 75: Reward = 38.0, Epsilon = 0.8005310565717831
# Episode 76: Reward = 24.0, Epsilon = 0.7981630172370991
# Episode 77: Reward = 15.0, Epsilon = 0.7958020713748902
# Episode 78: Reward = 16.0, Epsilon = 0.793448197736628
# Episode 79: Reward = 17.0, Epsilon = 0.7911013751374335
# Episode 80: Reward = 43.0, Epsilon = 0.7887615824558878
# Episode 81: Reward = 22.0, Epsilon = 0.7864287986338409
# Episode 82: Reward = 12.0, Epsilon = 0.7841030026762225
# Episode 83: Reward = 46.0, Epsilon = 0.7817841736508533
# Episode 84: Reward = 16.0, Epsilon = 0.7794722906882566
# Episode 85: Reward = 19.0, Epsilon = 0.77716733298147
# Episode 86: Reward = 28.0, Epsilon = 0.7748692797858587
# Episode 87: Reward = 15.0, Epsilon = 0.7725781104189283
# Episode 88: Reward = 25.0, Epsilon = 0.7702938042601392
# Episode 89: Reward = 18.0, Epsilon = 0.7680163407507202
# Episode 90: Reward = 14.0, Epsilon = 0.7657456993934846
# Episode 91: Reward = 23.0, Epsilon = 0.7634818597526449
# Episode 92: Reward = 28.0, Epsilon = 0.761224801453629
# Episode 93: Reward = 20.0, Epsilon = 0.7589745041828969
# Episode 94: Reward = 13.0, Epsilon = 0.7567309476877581
# Episode 95: Reward = 55.0, Epsilon = 0.7544941117761887
# Episode 96: Reward = 36.0, Epsilon = 0.7522639763166509
# Episode 97: Reward = 90.0, Epsilon = 0.7500405212379101
# Episode 98: Reward = 14.0, Epsilon = 0.7478237265288558
# Episode 99: Reward = 56.0, Epsilon = 0.7456135722383205
# Episode 100: Reward = 31.0, Epsilon = 0.7434100384749007
# Episode 101: Reward = 10.0, Epsilon = 0.7412131054067778
# Episode 102: Reward = 19.0, Epsilon = 0.7390227532615392
# Episode 103: Reward = 53.0, Epsilon = 0.7368389623260009
# Episode 104: Reward = 41.0, Epsilon = 0.7346617129460296
# Episode 105: Reward = 82.0, Epsilon = 0.7324909855263663
# Episode 106: Reward = 33.0, Epsilon = 0.7303267605304495
# Episode 107: Reward = 20.0, Epsilon = 0.7281690184802398
# Episode 108: Reward = 20.0, Epsilon = 0.726017739956044
# Episode 109: Reward = 34.0, Epsilon = 0.723872905596341
# Episode 110: Reward = 18.0, Epsilon = 0.7217344960976069
# Episode 111: Reward = 28.0, Epsilon = 0.719602492214142
# Episode 112: Reward = 55.0, Epsilon = 0.7174768747578968
# Episode 113: Reward = 37.0, Epsilon = 0.7153576245982999
# Episode 114: Reward = 86.0, Epsilon = 0.7132447226620855
# Episode 115: Reward = 48.0, Epsilon = 0.711138149933122
# Episode 116: Reward = 97.0, Epsilon = 0.7090378874522405
# Episode 117: Reward = 24.0, Epsilon = 0.7069439163170647
# Episode 118: Reward = 24.0, Epsilon = 0.70485621768184
# Episode 119: Reward = 38.0, Epsilon = 0.702774772757265
# Episode 120: Reward = 11.0, Epsilon = 0.7006995628103208
# Episode 121: Reward = 22.0, Epsilon = 0.698630569164104
# Episode 122: Reward = 14.0, Epsilon = 0.6965677731976582
# Episode 123: Reward = 54.0, Epsilon = 0.6945111563458054
# Episode 124: Reward = 30.0, Epsilon = 0.6924607000989802
# Episode 125: Reward = 34.0, Epsilon = 0.6904163860030624
# Episode 126: Reward = 35.0, Epsilon = 0.6883781956592115
# Episode 127: Reward = 15.0, Epsilon = 0.6863461107237007
# Episode 128: Reward = 47.0, Epsilon = 0.6843201129077516
# Episode 129: Reward = 23.0, Epsilon = 0.6823001839773704
# Episode 130: Reward = 27.0, Epsilon = 0.680286305753183
# Episode 131: Reward = 40.0, Epsilon = 0.6782784601102718
# Episode 132: Reward = 15.0, Epsilon = 0.6762766289780126
# Episode 133: Reward = 30.0, Epsilon = 0.6742807943399114
# Episode 134: Reward = 89.0, Epsilon = 0.6722909382334432
# Episode 135: Reward = 146.0, Epsilon = 0.6703070427498896
# Episode 136: Reward = 34.0, Epsilon = 0.668329090034178
# Episode 137: Reward = 94.0, Epsilon = 0.6663570622847201
# Episode 138: Reward = 25.0, Epsilon = 0.6643909417532533
# Episode 139: Reward = 69.0, Epsilon = 0.6624307107446795
# Episode 140: Reward = 81.0, Epsilon = 0.6604763516169062
# Episode 141: Reward = 112.0, Epsilon = 0.6585278467806882
# Episode 142: Reward = 23.0, Epsilon = 0.6565851786994689
# Episode 143: Reward = 35.0, Epsilon = 0.6546483298892222
# Episode 144: Reward = 89.0, Epsilon = 0.652717282918296
# Episode 145: Reward = 18.0, Epsilon = 0.6507920204072543
# Episode 146: Reward = 14.0, Epsilon = 0.6488725250287216
# Episode 147: Reward = 19.0, Epsilon = 0.6469587795072266
# Episode 148: Reward = 56.0, Epsilon = 0.6450507666190466
# Episode 149: Reward = 44.0, Epsilon = 0.6431484691920529
# Episode 150: Reward = 138.0, Epsilon = 0.6412518701055555
# Episode 151: Reward = 31.0, Epsilon = 0.6393609522901501
# Episode 152: Reward = 96.0, Epsilon = 0.6374756987275635
# Episode 153: Reward = 11.0, Epsilon = 0.635596092450501
# Episode 154: Reward = 65.0, Epsilon = 0.6337221165424931
# Episode 155: Reward = 18.0, Epsilon = 0.6318537541377444
# Episode 156: Reward = 102.0, Epsilon = 0.6299909884209803
# Episode 157: Reward = 72.0, Epsilon = 0.628133802627297
# Episode 158: Reward = 27.0, Epsilon = 0.6262821800420099
# Episode 159: Reward = 20.0, Epsilon = 0.624436104000503
# Episode 160: Reward = 122.0, Epsilon = 0.6225955578880794
# Episode 161: Reward = 61.0, Epsilon = 0.620760525139812
# Episode 162: Reward = 24.0, Epsilon = 0.6189309892403934
# Episode 163: Reward = 23.0, Epsilon = 0.6171069337239882
# Episode 164: Reward = 98.0, Epsilon = 0.6152883421740846
# Episode 165: Reward = 33.0, Epsilon = 0.6134751982233462
# Episode 166: Reward = 21.0, Epsilon = 0.6116674855534653
# Episode 167: Reward = 18.0, Epsilon = 0.6098651878950156
# Episode 168: Reward = 42.0, Epsilon = 0.608068289027306
# Episode 169: Reward = 22.0, Epsilon = 0.6062767727782348
# Episode 170: Reward = 27.0, Epsilon = 0.6044906230241432
# Episode 171: Reward = 15.0, Epsilon = 0.6027098236896717
# Episode 172: Reward = 33.0, Epsilon = 0.6009343587476144
# Episode 173: Reward = 29.0, Epsilon = 0.5991642122187745
# Episode 174: Reward = 15.0, Epsilon = 0.5973993681718215
# Episode 175: Reward = 16.0, Epsilon = 0.5956398107231469
# Episode 176: Reward = 111.0, Epsilon = 0.5938855240367219
# Episode 177: Reward = 20.0, Epsilon = 0.5921364923239545
# Episode 178: Reward = 24.0, Epsilon = 0.5903926998435474
# Episode 179: Reward = 21.0, Epsilon = 0.5886541309013565
# Episode 180: Reward = 15.0, Epsilon = 0.5869207698502498
# Episode 181: Reward = 16.0, Epsilon = 0.5851926010899657
# Episode 182: Reward = 60.0, Epsilon = 0.5834696090669742
# Episode 183: Reward = 63.0, Epsilon = 0.5817517782743351
# Episode 184: Reward = 46.0, Epsilon = 0.5800390932515599
# Episode 185: Reward = 19.0, Epsilon = 0.5783315385844716
# Episode 186: Reward = 16.0, Epsilon = 0.5766290989050669
# Episode 187: Reward = 18.0, Epsilon = 0.574931758891377
# Episode 188: Reward = 33.0, Epsilon = 0.5732395032673305
# Episode 189: Reward = 68.0, Epsilon = 0.5715523168026153
# Episode 190: Reward = 27.0, Epsilon = 0.5698701843125418
# Episode 191: Reward = 28.0, Epsilon = 0.5681930906579061
# Episode 192: Reward = 52.0, Epsilon = 0.5665210207448542
# Episode 193: Reward = 23.0, Epsilon = 0.5648539595247456
# Episode 194: Reward = 27.0, Epsilon = 0.5631918919940179
# Episode 195: Reward = 17.0, Epsilon = 0.5615348031940521
# Episode 196: Reward = 10.0, Epsilon = 0.5598826782110382
# Episode 197: Reward = 134.0, Epsilon = 0.5582355021758396
# Episode 198: Reward = 13.0, Epsilon = 0.5565932602638612
# Episode 199: Reward = 47.0, Epsilon = 0.5549559376949149
# Episode 200: Reward = 21.0, Epsilon = 0.5533235197330862
# Episode 201: Reward = 41.0, Epsilon = 0.5516959916866025
# Episode 202: Reward = 84.0, Epsilon = 0.5500733389077004
# Episode 203: Reward = 107.0, Epsilon = 0.548455546792494
# Episode 204: Reward = 50.0, Epsilon = 0.5468426007808435
# Episode 205: Reward = 47.0, Epsilon = 0.5452344863562234
# Episode 206: Reward = 45.0, Epsilon = 0.5436311890455935
# Episode 207: Reward = 73.0, Epsilon = 0.5420326944192669
# Episode 208: Reward = 85.0, Epsilon = 0.5404389880907815
# Episode 209: Reward = 21.0, Epsilon = 0.5388500557167692
# Episode 210: Reward = 151.0, Epsilon = 0.5372658829968282
# Episode 211: Reward = 36.0, Epsilon = 0.5356864556733932
# Episode 212: Reward = 41.0, Epsilon = 0.5341117595316076
# Episode 213: Reward = 151.0, Epsilon = 0.5325417803991955
# Episode 214: Reward = 100.0, Epsilon = 0.5309765041463343
# Episode 215: Reward = 37.0, Epsilon = 0.5294159166855269
# Episode 216: Reward = 115.0, Epsilon = 0.5278600039714758
# Episode 217: Reward = 200.0, Epsilon = 0.526308752000956
# Episode 218: Reward = 21.0, Epsilon = 0.5247621468126892
# Episode 219: Reward = 15.0, Epsilon = 0.5232201744872184
# Episode 220: Reward = 200.0, Epsilon = 0.5216828211467822
# Episode 221: Reward = 200.0, Epsilon = 0.5201500729551902
# Episode 222: Reward = 15.0, Epsilon = 0.5186219161176985
# Episode 223: Reward = 191.0, Epsilon = 0.5170983368808848
# Episode 224: Reward = 124.0, Epsilon = 0.515579321532526
# Episode 225: Reward = 159.0, Epsilon = 0.5140648564014737
# Episode 226: Reward = 30.0, Epsilon = 0.5125549278575314
# Episode 227: Reward = 25.0, Epsilon = 0.5110495223113322
# Episode 228: Reward = 76.0, Epsilon = 0.5095486262142156
# Episode 229: Reward = 124.0, Epsilon = 0.5080522260581071
# Episode 230: Reward = 16.0, Epsilon = 0.5065603083753949
# Episode 231: Reward = 111.0, Epsilon = 0.5050728597388099
# Episode 232: Reward = 97.0, Epsilon = 0.5035898667613044
# Episode 233: Reward = 100.0, Epsilon = 0.5021113160959313
# Episode 234: Reward = 168.0, Epsilon = 0.500637194435725
# Episode 235: Reward = 58.0, Epsilon = 0.49916748851358034
# Episode 236: Reward = 100.0, Epsilon = 0.4977021851021341
# Episode 237: Reward = 171.0, Epsilon = 0.49624127101364585
# Episode 238: Reward = 16.0, Epsilon = 0.49478473309987886
# Episode 239: Reward = 30.0, Epsilon = 0.493332558251982
# Episode 240: Reward = 90.0, Epsilon = 0.491884733400372
# Episode 241: Reward = 136.0, Epsilon = 0.4904412455146152
# Episode 242: Reward = 51.0, Epsilon = 0.48900208160331116
# Episode 243: Reward = 28.0, Epsilon = 0.48756722871397473
# Episode 244: Reward = 143.0, Epsilon = 0.4861366739329203
# Episode 245: Reward = 77.0, Epsilon = 0.4847104043851452
# Episode 246: Reward = 18.0, Epsilon = 0.48328840723421385
# Episode 247: Reward = 99.0, Epsilon = 0.4818706696821423
# Episode 248: Reward = 32.0, Epsilon = 0.480457178969283
# Episode 249: Reward = 149.0, Epsilon = 0.47904792237421007
# Episode 250: Reward = 144.0, Epsilon = 0.47764288721360454
# Episode 251: Reward = 186.0, Epsilon = 0.47624206084214055
# Episode 252: Reward = 84.0, Epsilon = 0.4748454306523713
# Episode 253: Reward = 39.0, Epsilon = 0.4734529840746156
# Episode 254: Reward = 100.0, Epsilon = 0.47206470857684485
# Episode 255: Reward = 61.0, Epsilon = 0.4706805916645702
# Episode 256: Reward = 103.0, Epsilon = 0.4693006208807302
# Episode 257: Reward = 101.0, Epsilon = 0.4679247838055784
# Episode 258: Reward = 138.0, Epsilon = 0.4665530680565719
# Episode 259: Reward = 126.0, Epsilon = 0.46518546128825955
# Episode 260: Reward = 54.0, Epsilon = 0.4638219511921713
# Episode 261: Reward = 94.0, Epsilon = 0.46246252549670713
# Episode 262: Reward = 19.0, Epsilon = 0.4611071719670265
# Episode 263: Reward = 137.0, Epsilon = 0.45975587840493853
# Episode 264: Reward = 70.0, Epsilon = 0.4584086326487921
# Episode 265: Reward = 146.0, Epsilon = 0.4570654225733663
# Episode 266: Reward = 151.0, Epsilon = 0.4557262360897613
# Episode 267: Reward = 95.0, Epsilon = 0.4543910611452898
# Episode 268: Reward = 83.0, Epsilon = 0.45305988572336825
# Episode 269: Reward = 120.0, Epsilon = 0.4517326978434088
# Episode 270: Reward = 109.0, Epsilon = 0.4504094855607117
# Episode 271: Reward = 125.0, Epsilon = 0.44909023696635736
# Episode 272: Reward = 22.0, Epsilon = 0.4477749401870996
# Episode 273: Reward = 12.0, Epsilon = 0.44646358338525854
# Episode 274: Reward = 20.0, Epsilon = 0.4451561547586141
# Episode 275: Reward = 29.0, Epsilon = 0.4438526425402997
# Episode 276: Reward = 112.0, Epsilon = 0.44255303499869675
# Episode 277: Reward = 55.0, Epsilon = 0.44125732043732846
# Episode 278: Reward = 94.0, Epsilon = 0.43996548719475514
# Episode 279: Reward = 135.0, Epsilon = 0.4386775236444688
# Episode 280: Reward = 50.0, Epsilon = 0.4373934181947889
# Episode 281: Reward = 36.0, Epsilon = 0.4361131592887576
# Episode 282: Reward = 126.0, Epsilon = 0.4348367354040362
# Episode 283: Reward = 106.0, Epsilon = 0.43356413505280106
# Episode 284: Reward = 151.0, Epsilon = 0.43229534678164044
# Episode 285: Reward = 34.0, Epsilon = 0.4310303591714514
# Episode 286: Reward = 14.0, Epsilon = 0.4297691608373368
# Episode 287: Reward = 16.0, Epsilon = 0.4285117404285032
# Episode 288: Reward = 86.0, Epsilon = 0.4272580866281584
# Episode 289: Reward = 27.0, Epsilon = 0.4260081881534098
# Episode 290: Reward = 39.0, Epsilon = 0.42476203375516264
# Episode 291: Reward = 175.0, Epsilon = 0.4235196122180188
# Episode 292: Reward = 74.0, Epsilon = 0.4222809123601763
# Episode 293: Reward = 136.0, Epsilon = 0.4210459230333279
# Episode 294: Reward = 115.0, Epsilon = 0.4198146331225614
# Episode 295: Reward = 84.0, Epsilon = 0.4185870315462592
# Episode 296: Reward = 116.0, Epsilon = 0.41736310725599884
# Episode 297: Reward = 92.0, Epsilon = 0.41614284923645356
# Episode 298: Reward = 143.0, Epsilon = 0.41492624650529286
# Episode 299: Reward = 44.0, Epsilon = 0.41371328811308394
# Episode 300: Reward = 151.0, Epsilon = 0.4125039631431931
# Episode 301: Reward = 130.0, Epsilon = 0.41129826071168746
# Episode 493: Reward = 168.0, Epsilon = 0.23558678552969994
# Episode 494: Reward = 164.0, Epsilon = 0.2349110392992661
# Episode 495: Reward = 149.0, Epsilon = 0.23423731726970407
# Episode 496: Reward = 182.0, Epsilon = 0.2335656133775111
# Episode 497: Reward = 147.0, Epsilon = 0.2328959215773476
# Episode 498: Reward = 134.0, Epsilon = 0.23222823584198285
# Episode 499: Reward = 150.0, Epsilon = 0.23156255016224064
# Episode 500: Reward = 153.0, Epsilon = 0.23089885854694553
# Episode 501: Reward = 147.0, Epsilon = 0.23023715502286835
# Episode 502: Reward = 148.0, Epsilon = 0.22957743363467303
# Episode 503: Reward = 25.0, Epsilon = 0.22891968844486255
# Episode 504: Reward = 174.0, Epsilon = 0.22826391353372577
# Episode 505: Reward = 142.0, Epsilon = 0.22761010299928408
# Episode 506: Reward = 153.0, Epsilon = 0.22695825095723826
# Episode 507: Reward = 150.0, Epsilon = 0.2263083515409155
# Episode 508: Reward = 23.0, Epsilon = 0.22566039890121672
# Episode 509: Reward = 160.0, Epsilon = 0.22501438720656372
# Episode 510: Reward = 168.0, Epsilon = 0.224370310642847
# Episode 511: Reward = 193.0, Epsilon = 0.22372816341337298
# Episode 512: Reward = 200.0, Epsilon = 0.2230879397388124
# Episode 513: Reward = 163.0, Epsilon = 0.22244963385714783
# Episode 514: Reward = 173.0, Epsilon = 0.22181324002362196
# Episode 515: Reward = 165.0, Epsilon = 0.22117875251068608
# Episode 516: Reward = 166.0, Epsilon = 0.2205461656079482
# Episode 517: Reward = 140.0, Epsilon = 0.21991547362212205
# Episode 518: Reward = 149.0, Epsilon = 0.21928667087697534
# Episode 519: Reward = 18.0, Epsilon = 0.2186597517132793
# Episode 520: Reward = 147.0, Epsilon = 0.21803471048875708
# Episode 521: Reward = 152.0, Epsilon = 0.21741154157803352
# Episode 522: Reward = 157.0, Epsilon = 0.21679023937258418
# Episode 523: Reward = 167.0, Epsilon = 0.21617079828068503
# Episode 524: Reward = 149.0, Epsilon = 0.21555321272736205
# Episode 525: Reward = 149.0, Epsilon = 0.21493747715434114
# Episode 526: Reward = 157.0, Epsilon = 0.21432358601999785
# Episode 527: Reward = 151.0, Epsilon = 0.21371153379930802
# Episode 528: Reward = 154.0, Epsilon = 0.2131013149837974
# Episode 529: Reward = 157.0, Epsilon = 0.21249292408149256
# Episode 530: Reward = 148.0, Epsilon = 0.2118863556168713
# Episode 531: Reward = 143.0, Epsilon = 0.21128160413081332
# Episode 532: Reward = 168.0, Epsilon = 0.21067866418055115
# Episode 533: Reward = 154.0, Epsilon = 0.21007753033962123
# Episode 534: Reward = 158.0, Epsilon = 0.20947819719781485
# Episode 535: Reward = 150.0, Epsilon = 0.20888065936112976
# Episode 536: Reward = 163.0, Epsilon = 0.20828491145172132
# Episode 537: Reward = 147.0, Epsilon = 0.20769094810785443
# Episode 538: Reward = 159.0, Epsilon = 0.20709876398385488
# Episode 539: Reward = 161.0, Epsilon = 0.2065083537500616
# Episode 540: Reward = 158.0, Epsilon = 0.2059197120927785
# Episode 684: Reward = 141.0, Epsilon = 0.13719291416808627
# Episode 685: Reward = 139.0, Epsilon = 0.13681190722175668
# Episode 686: Reward = 150.0, Epsilon = 0.1364320415834481
# Episode 687: Reward = 200.0, Epsilon = 0.13605331383436714
# Episode 688: Reward = 156.0, Epsilon = 0.13567572056596153
# Episode 689: Reward = 148.0, Epsilon = 0.13529925837988932
# Episode 690: Reward = 153.0, Epsilon = 0.13492392388798838
# Episode 691: Reward = 148.0, Epsilon = 0.1345497137122456
# Episode 692: Reward = 164.0, Epsilon = 0.13417662448476694
# Episode 693: Reward = 159.0, Epsilon = 0.13380465284774684
# Episode 694: Reward = 169.0, Epsilon = 0.13343379545343814
# Episode 695: Reward = 156.0, Epsilon = 0.1330640489641216
# Episode 696: Reward = 179.0, Epsilon = 0.13269541005207644
# Episode 697: Reward = 177.0, Epsilon = 0.13232787539954993
# Episode 698: Reward = 166.0, Epsilon = 0.13196144169872778
# Episode 699: Reward = 148.0, Epsilon = 0.13159610565170413
# Episode 700: Reward = 154.0, Epsilon = 0.13123186397045208
# Episode 701: Reward = 168.0, Epsilon = 0.13086871337679412
# Episode 702: Reward = 144.0, Epsilon = 0.13050665060237243
# Episode 703: Reward = 143.0, Epsilon = 0.13014567238861954
# Episode 704: Reward = 138.0, Epsilon = 0.12978577548672915
# Episode 705: Reward = 155.0, Epsilon = 0.12942695665762668
# Episode 706: Reward = 166.0, Epsilon = 0.12906921267194033
# Episode 707: Reward = 143.0, Epsilon = 0.12871254030997167
# Episode 708: Reward = 159.0, Epsilon = 0.12835693636166712
# Episode 709: Reward = 150.0, Epsilon = 0.12800239762658874
# Episode 710: Reward = 150.0, Epsilon = 0.12764892091388555
# Episode 711: Reward = 179.0, Epsilon = 0.12729650304226467
# Episode 712: Reward = 184.0, Epsilon = 0.12694514083996294
# Episode 713: Reward = 145.0, Epsilon = 0.12659483114471815
# Episode 714: Reward = 162.0, Epsilon = 0.12624557080374071
# Episode 715: Reward = 168.0, Epsilon = 0.1258973566736851
# Episode 716: Reward = 151.0, Epsilon = 0.1255501856206219
# Episode 717: Reward = 146.0, Epsilon = 0.1252040545200092
# Episode 718: Reward = 157.0, Epsilon = 0.12485896025666489
# Episode 719: Reward = 189.0, Epsilon = 0.12451489972473813
# Episode 720: Reward = 182.0, Epsilon = 0.12417186982768187
# Episode 721: Reward = 157.0, Epsilon = 0.12382986747822473
# Episode 722: Reward = 156.0, Epsilon = 0.12348888959834328
# Episode 723: Reward = 142.0, Epsilon = 0.12314893311923422
# Episode 724: Reward = 147.0, Epsilon = 0.12280999498128699
# Episode 725: Reward = 157.0, Epsilon = 0.12247207213405607
# Episode 726: Reward = 153.0, Epsilon = 0.12213516153623358
# Episode 727: Reward = 158.0, Epsilon = 0.12179926015562179
# Episode 728: Reward = 148.0, Epsilon = 0.12146436496910604
# Episode 729: Reward = 156.0, Epsilon = 0.12113047296262744
# Episode 730: Reward = 161.0, Epsilon = 0.12079758113115559
# Episode 731: Reward = 154.0, Epsilon = 0.1204656864786618
# Episode 732: Reward = 130.0, Epsilon = 0.12013478601809197
# Episode 733: Reward = 169.0, Epsilon = 0.11980487677133975
# Episode 734: Reward = 135.0, Epsilon = 0.11947595576921961
# Episode 735: Reward = 141.0, Epsilon = 0.11914802005144036
# Episode 736: Reward = 131.0, Epsilon = 0.11882106666657831
# Episode 737: Reward = 200.0, Epsilon = 0.11849509267205087
# Episode 738: Reward = 200.0, Epsilon = 0.11817009513408976
# Episode 739: Reward = 155.0, Epsilon = 0.11784607112771502
# Episode 740: Reward = 200.0, Epsilon = 0.11752301773670837
# Episode 741: Reward = 186.0, Epsilon = 0.11720093205358718
# Episode 742: Reward = 173.0, Epsilon = 0.11687981117957805
# Episode 743: Reward = 161.0, Epsilon = 0.11655965222459096
# Episode 744: Reward = 151.0, Epsilon = 0.11624045230719318
# Episode 745: Reward = 141.0, Epsilon = 0.11592220855458332
# Episode 746: Reward = 141.0, Epsilon = 0.11560491810256539
# Episode 747: Reward = 154.0, Epsilon = 0.11528857809552322
# Episode 748: Reward = 150.0, Epsilon = 0.11497318568639461
# Episode 749: Reward = 156.0, Epsilon = 0.11465873803664578
# Episode 750: Reward = 152.0, Epsilon = 0.11434523231624569
# Episode 751: Reward = 147.0, Epsilon = 0.11403266570364078
# Episode 752: Reward = 163.0, Epsilon = 0.11372103538572942
# Episode 753: Reward = 164.0, Epsilon = 0.11341033855783668
# Episode 754: Reward = 156.0, Epsilon = 0.11310057242368894
# Episode 755: Reward = 195.0, Epsilon = 0.11279173419538895
# Episode 756: Reward = 151.0, Epsilon = 0.11248382109339056
# Episode 757: Reward = 163.0, Epsilon = 0.11217683034647383
# Episode 758: Reward = 141.0, Epsilon = 0.11187075919171986
# Episode 759: Reward = 148.0, Epsilon = 0.11156560487448623
# Episode 760: Reward = 141.0, Epsilon = 0.11126136464838206
# Episode 761: Reward = 146.0, Epsilon = 0.11095803577524327
# Episode 762: Reward = 194.0, Epsilon = 0.11065561552510789
# Episode 763: Reward = 200.0, Epsilon = 0.11035410117619167
# Episode 764: Reward = 186.0, Epsilon = 0.1100534900148634
# Episode 765: Reward = 200.0, Epsilon = 0.1097537793356207
# Episode 766: Reward = 161.0, Epsilon = 0.10945496644106528
# Episode 767: Reward = 170.0, Epsilon = 0.10915704864187917
# Episode 768: Reward = 163.0, Epsilon = 0.10886002325680014
# Episode 769: Reward = 164.0, Epsilon = 0.10856388761259778
# Episode 770: Reward = 200.0, Epsilon = 0.10826863904404918
# Episode 771: Reward = 200.0, Epsilon = 0.1079742748939153
# Episode 772: Reward = 187.0, Epsilon = 0.10768079251291685
# Episode 773: Reward = 161.0, Epsilon = 0.10738818925971029
# Episode 774: Reward = 188.0, Epsilon = 0.10709646250086446
# Episode 775: Reward = 200.0, Epsilon = 0.10680560961083654
# Episode 776: Reward = 170.0, Epsilon = 0.10651562797194858
# Episode 777: Reward = 193.0, Epsilon = 0.10622651497436382
# Episode 778: Reward = 200.0, Epsilon = 0.10593826801606335
# Episode 779: Reward = 188.0, Epsilon = 0.10565088450282262
# Episode 780: Reward = 200.0, Epsilon = 0.10536436184818809
# Episode 781: Reward = 200.0, Epsilon = 0.10507869747345389
# Episode 782: Reward = 200.0, Epsilon = 0.1047938888076387
# Episode 783: Reward = 200.0, Epsilon = 0.10450993328746264
# Episode 784: Reward = 200.0, Epsilon = 0.10422682835732415
# Episode 785: Reward = 200.0, Epsilon = 0.10394457146927688
# Episode 786: Reward = 196.0, Epsilon = 0.10366316008300694
# Episode 787: Reward = 200.0, Epsilon = 0.10338259166581
# Episode 788: Reward = 200.0, Epsilon = 0.10310286369256841
# Episode 789: Reward = 200.0, Epsilon = 0.10282397364572846
# Episode 790: Reward = 200.0, Epsilon = 0.10254591901527788
# Episode 791: Reward = 200.0, Epsilon = 0.10226869729872312
# Episode 792: Reward = 200.0, Epsilon = 0.1019923060010669
# Episode 793: Reward = 200.0, Epsilon = 0.10171674263478561
# Episode 794: Reward = 169.0, Epsilon = 0.10144200471980712
# Episode 795: Reward = 200.0, Epsilon = 0.10116808978348835
# Episode 796: Reward = 196.0, Epsilon = 0.10089499536059303
# Episode 797: Reward = 200.0, Epsilon = 0.10062271899326947
# Episode 798: Reward = 169.0, Epsilon = 0.10035125823102856
# Episode 799: Reward = 200.0, Epsilon = 0.10008061063072159
# Episode 800: Reward = 200.0, Epsilon = 0.0998107737565184
# Episode 801: Reward = 198.0, Epsilon = 0.09954174517988518
# Episode 802: Reward = 200.0, Epsilon = 0.09927352247956299
# Episode 803: Reward = 200.0, Epsilon = 0.09900610324154571
# Episode 804: Reward = 200.0, Epsilon = 0.09873948505905844
# Episode 805: Reward = 200.0, Epsilon = 0.09847366553253566
# Episode 806: Reward = 200.0, Epsilon = 0.09820864226959986
# Episode 807: Reward = 196.0, Epsilon = 0.0979444128850399
# Episode 808: Reward = 200.0, Epsilon = 0.09768097500078957
# Episode 809: Reward = 200.0, Epsilon = 0.09741832624590603
# Episode 810: Reward = 200.0, Epsilon = 0.09715646425654882
# Episode 811: Reward = 200.0, Epsilon = 0.09689538667595823
# Episode 812: Reward = 200.0, Epsilon = 0.09663509115443425
# Episode 813: Reward = 200.0, Epsilon = 0.09637557534931544
# Episode 814: Reward = 200.0, Epsilon = 0.09611683692495782
# Episode 815: Reward = 174.0, Epsilon = 0.09585887355271383
# Episode 816: Reward = 200.0, Epsilon = 0.09560168291091133
# Episode 817: Reward = 200.0, Epsilon = 0.09534526268483286
# Episode 818: Reward = 200.0, Epsilon = 0.09508961056669461
# Episode 819: Reward = 154.0, Epsilon = 0.09483472425562586
# Episode 820: Reward = 182.0, Epsilon = 0.094580601457648
# Episode 821: Reward = 200.0, Epsilon = 0.0943272398856542
# Episode 822: Reward = 172.0, Epsilon = 0.09407463725938857
# Episode 823: Reward = 181.0, Epsilon = 0.09382279130542581
# Episode 824: Reward = 152.0, Epsilon = 0.09357169975715057
# Episode 825: Reward = 156.0, Epsilon = 0.09332136035473725
# Episode 826: Reward = 172.0, Epsilon = 0.09307177084512955
# Episode 827: Reward = 128.0, Epsilon = 0.09282292898202023
# Episode 828: Reward = 106.0, Epsilon = 0.09257483252583075
# Episode 829: Reward = 135.0, Epsilon = 0.09232747924369139
# Episode 830: Reward = 100.0, Epsilon = 0.09208086690942092
# Episode 831: Reward = 111.0, Epsilon = 0.09183499330350675
# Episode 832: Reward = 98.0, Epsilon = 0.09158985621308463
# Episode 833: Reward = 100.0, Epsilon = 0.09134545343191919
# Episode 834: Reward = 114.0, Epsilon = 0.09110178276038369
# Episode 835: Reward = 119.0, Epsilon = 0.09085884200544052
# Episode 836: Reward = 94.0, Epsilon = 0.09061662898062116
# Episode 837: Reward = 98.0, Epsilon = 0.0903751415060068
# Episode 838: Reward = 154.0, Epsilon = 0.09013437740820851
# Episode 839: Reward = 109.0, Epsilon = 0.08989433452034783
# Episode 840: Reward = 124.0, Epsilon = 0.0896550106820371
# Episode 841: Reward = 153.0, Epsilon = 0.08941640373936016
# Episode 842: Reward = 17.0, Epsilon = 0.08917851154485297
# Episode 843: Reward = 104.0, Epsilon = 0.08894133195748416
# Episode 844: Reward = 117.0, Epsilon = 0.08870486284263578
# Episode 845: Reward = 99.0, Epsilon = 0.08846910207208424
# Episode 846: Reward = 19.0, Epsilon = 0.08823404752398102
# Episode 847: Reward = 91.0, Epsilon = 0.08799969708283362
# Episode 848: Reward = 77.0, Epsilon = 0.08776604863948644
# Episode 849: Reward = 114.0, Epsilon = 0.08753310009110192
# Episode 850: Reward = 76.0, Epsilon = 0.08730084934114159
# Episode 851: Reward = 15.0, Epsilon = 0.08706929429934714
# Episode 852: Reward = 17.0, Epsilon = 0.08683843288172156
# Episode 853: Reward = 144.0, Epsilon = 0.08660826301051058
# Episode 854: Reward = 86.0, Epsilon = 0.08637878261418384
# Episode 855: Reward = 132.0, Epsilon = 0.08614998962741616
# Episode 856: Reward = 115.0, Epsilon = 0.08592188199106911
# Episode 857: Reward = 103.0, Epsilon = 0.08569445765217247
# Episode 858: Reward = 147.0, Epsilon = 0.08546771456390566
# Episode 859: Reward = 165.0, Epsilon = 0.08524165068557932
# Episode 860: Reward = 89.0, Epsilon = 0.08501626398261702
# Episode 861: Reward = 122.0, Epsilon = 0.08479155242653691
# Episode 862: Reward = 91.0, Epsilon = 0.08456751399493354
# Episode 863: Reward = 114.0, Epsilon = 0.08434414667145941
# Episode 864: Reward = 137.0, Epsilon = 0.08412144844580714
# Episode 865: Reward = 93.0, Epsilon = 0.0838994173136912
# Episode 866: Reward = 123.0, Epsilon = 0.08367805127682995
# Episode 867: Reward = 87.0, Epsilon = 0.08345734834292748
# Episode 868: Reward = 119.0, Epsilon = 0.08323730652565593
# Episode 869: Reward = 126.0, Epsilon = 0.08301792384463748
# Episode 870: Reward = 119.0, Epsilon = 0.08279919832542652
# Episode 871: Reward = 100.0, Epsilon = 0.08258112799949184
# Episode 872: Reward = 99.0, Epsilon = 0.0823637109041991
# Episode 873: Reward = 90.0, Epsilon = 0.08214694508279295
# Episode 874: Reward = 82.0, Epsilon = 0.08193082858437956
# Episode 875: Reward = 14.0, Epsilon = 0.08171535946390894
# Episode 876: Reward = 75.0, Epsilon = 0.08150053578215756
# Episode 877: Reward = 15.0, Epsilon = 0.08128635560571086
# Episode 878: Reward = 12.0, Epsilon = 0.08107281700694582
# Episode 879: Reward = 81.0, Epsilon = 0.08085991806401356
# Episode 880: Reward = 18.0, Epsilon = 0.08064765686082218
# Episode 881: Reward = 86.0, Epsilon = 0.08043603148701943
# Episode 882: Reward = 14.0, Epsilon = 0.08022504003797552
# Episode 883: Reward = 83.0, Epsilon = 0.08001468061476594
# Episode 884: Reward = 17.0, Epsilon = 0.0798049513241545
# Episode 885: Reward = 15.0, Epsilon = 0.07959585027857616
# Episode 886: Reward = 14.0, Epsilon = 0.07938737559612012
# Episode 887: Reward = 13.0, Epsilon = 0.07917952540051279
# Episode 888: Reward = 16.0, Epsilon = 0.07897229782110102
# Episode 889: Reward = 12.0, Epsilon = 0.0787656909928352
# Episode 890: Reward = 16.0, Epsilon = 0.07855970305625253
# Episode 891: Reward = 20.0, Epsilon = 0.0783543321574601
# Episode 892: Reward = 16.0, Epsilon = 0.07814957644811847
# Episode 893: Reward = 14.0, Epsilon = 0.07794543408542491
# Episode 894: Reward = 15.0, Epsilon = 0.07774190323209677
# Episode 895: Reward = 79.0, Epsilon = 0.07753898205635494
# Episode 896: Reward = 17.0, Epsilon = 0.0773366687319075
# Episode 897: Reward = 65.0, Epsilon = 0.0771349614379332
# Episode 898: Reward = 16.0, Epsilon = 0.076933858359065
# Episode 899: Reward = 14.0, Epsilon = 0.0767333576853738
# Episode 900: Reward = 20.0, Epsilon = 0.07653345761235224
# Episode 901: Reward = 77.0, Epsilon = 0.07633415634089832
# Episode 902: Reward = 16.0, Epsilon = 0.0761354520772992
# Episode 903: Reward = 17.0, Epsilon = 0.07593734303321517
# Episode 904: Reward = 86.0, Epsilon = 0.07573982742566354
# Episode 905: Reward = 78.0, Epsilon = 0.07554290347700249
# Episode 906: Reward = 85.0, Epsilon = 0.07534656941491513
# Episode 907: Reward = 15.0, Epsilon = 0.07515082347239359
# Episode 908: Reward = 13.0, Epsilon = 0.07495566388772308
# Episode 909: Reward = 102.0, Epsilon = 0.07476108890446603
# Episode 910: Reward = 84.0, Epsilon = 0.07456709677144624
# Episode 911: Reward = 85.0, Epsilon = 0.07437368574273322
# Episode 912: Reward = 83.0, Epsilon = 0.0741808540776264
# Episode 913: Reward = 80.0, Epsilon = 0.07398860004063953
# Episode 914: Reward = 75.0, Epsilon = 0.07379692190148492
# Episode 915: Reward = 102.0, Epsilon = 0.07360581793505805
# Episode 916: Reward = 103.0, Epsilon = 0.07341528642142194
# Episode 917: Reward = 117.0, Epsilon = 0.07322532564579169
# Episode 918: Reward = 90.0, Epsilon = 0.07303593389851902
# Episode 919: Reward = 86.0, Epsilon = 0.0728471094750769
# Episode 920: Reward = 18.0, Epsilon = 0.07265885067604429
# Episode 921: Reward = 17.0, Epsilon = 0.07247115580709074
# Episode 922: Reward = 69.0, Epsilon = 0.07228402317896111
# Episode 923: Reward = 15.0, Epsilon = 0.0720974511074605
# Episode 924: Reward = 75.0, Epsilon = 0.07191143791343903
# Episode 925: Reward = 16.0, Epsilon = 0.0717259819227767
# Episode 926: Reward = 77.0, Epsilon = 0.0715410814663683
# Episode 927: Reward = 14.0, Epsilon = 0.07135673488010849
# Episode 928: Reward = 79.0, Epsilon = 0.07117294050487677
# Episode 929: Reward = 73.0, Epsilon = 0.07098969668652252
# Episode 930: Reward = 70.0, Epsilon = 0.07080700177585013
# Episode 931: Reward = 87.0, Epsilon = 0.07062485412860416
# Episode 932: Reward = 80.0, Epsilon = 0.07044325210545456
# Episode 933: Reward = 78.0, Epsilon = 0.07026219407198192
# Episode 934: Reward = 75.0, Epsilon = 0.07008167839866268
# Episode 935: Reward = 84.0, Epsilon = 0.06990170346085459
# Episode 936: Reward = 85.0, Epsilon = 0.06972226763878196
# Episode 937: Reward = 16.0, Epsilon = 0.06954336931752127
# Episode 938: Reward = 82.0, Epsilon = 0.0693650068869863
# Episode 939: Reward = 14.0, Epsilon = 0.06918717874191402
# Episode 940: Reward = 68.0, Epsilon = 0.06900988328184997
# Episode 941: Reward = 19.0, Epsilon = 0.06883311891113375
# Episode 942: Reward = 16.0, Epsilon = 0.06865688403888484
# Episode 943: Reward = 17.0, Epsilon = 0.06848117707898822
# Episode 944: Reward = 14.0, Epsilon = 0.06830599645008009
# Episode 945: Reward = 75.0, Epsilon = 0.06813134057553356
# Episode 946: Reward = 18.0, Epsilon = 0.06795720788344459
# Episode 947: Reward = 84.0, Epsilon = 0.06778359680661777
# Episode 948: Reward = 79.0, Epsilon = 0.06761050578255229
# Episode 949: Reward = 17.0, Epsilon = 0.06743793325342769
# Episode 950: Reward = 20.0, Epsilon = 0.06726587766609007
# Episode 951: Reward = 84.0, Epsilon = 0.067094337472038
# Episode 952: Reward = 11.0, Epsilon = 0.06692331112740858
# Episode 953: Reward = 17.0, Epsilon = 0.06675279709296353
# Episode 954: Reward = 17.0, Epsilon = 0.0665827938340754
# Episode 955: Reward = 77.0, Epsilon = 0.06641329982071369
# Episode 956: Reward = 16.0, Epsilon = 0.0662443135274312
# Episode 957: Reward = 80.0, Epsilon = 0.06607583343335006
# Episode 958: Reward = 14.0, Epsilon = 0.06590785802214835
# Episode 959: Reward = 19.0, Epsilon = 0.06574038578204622
# Episode 960: Reward = 84.0, Epsilon = 0.06557341520579238
# Episode 961: Reward = 68.0, Epsilon = 0.06540694479065051
# Episode 962: Reward = 95.0, Epsilon = 0.06524097303838575
# Episode 963: Reward = 12.0, Epsilon = 0.0650754984552512
# Episode 964: Reward = 14.0, Epsilon = 0.06491051955197454
# Episode 965: Reward = 72.0, Epsilon = 0.06474603484374447
# Episode 966: Reward = 73.0, Epsilon = 0.06458204285019753
# Episode 967: Reward = 83.0, Epsilon = 0.06441854209540467
# Episode 968: Reward = 16.0, Epsilon = 0.064255531107858
# Episode 969: Reward = 15.0, Epsilon = 0.06409300842045752
# Episode 970: Reward = 17.0, Epsilon = 0.06393097257049796
# Episode 971: Reward = 18.0, Epsilon = 0.06376942209965555
# Episode 972: Reward = 13.0, Epsilon = 0.06360835555397501
# Episode 973: Reward = 17.0, Epsilon = 0.0634477714838563
# Episode 974: Reward = 79.0, Epsilon = 0.06328766844404171
# Episode 975: Reward = 13.0, Epsilon = 0.0631280449936028
# Episode 976: Reward = 17.0, Epsilon = 0.06296889969592748
# Episode 977: Reward = 14.0, Epsilon = 0.06281023111870694
# Episode 978: Reward = 18.0, Epsilon = 0.06265203783392294
# Episode 979: Reward = 17.0, Epsilon = 0.06249431841783484
# Episode 980: Reward = 18.0, Epsilon = 0.06233707145096686
# Episode 981: Reward = 16.0, Epsilon = 0.062180295518095195
# Episode 982: Reward = 86.0, Epsilon = 0.06202398920823541
# Episode 983: Reward = 82.0, Epsilon = 0.061868151114629684
# Episode 984: Reward = 74.0, Epsilon = 0.061712779834734076
# Episode 985: Reward = 85.0, Epsilon = 0.06155787397020603
# Episode 986: Reward = 16.0, Epsilon = 0.06140343212689175
# Episode 987: Reward = 16.0, Epsilon = 0.0612494529148136
# Episode 988: Reward = 81.0, Epsilon = 0.06109593494815759
# Episode 989: Reward = 80.0, Epsilon = 0.06094287684526102
# Episode 990: Reward = 75.0, Epsilon = 0.06079027722859992
# Episode 991: Reward = 87.0, Epsilon = 0.060638134724776735
# Episode 992: Reward = 18.0, Epsilon = 0.060486447964507854
# Episode 993: Reward = 18.0, Epsilon = 0.060335215582611436
# Episode 994: Reward = 16.0, Epsilon = 0.06018443621799503
# Episode 995: Reward = 12.0, Epsilon = 0.06003410851364335
# Episode 996: Reward = 13.0, Epsilon = 0.059884231116606006
# Episode 997: Reward = 15.0, Epsilon = 0.05973480267798542
# Episode 998: Reward = 16.0, Epsilon = 0.05958582185292465
# Episode 999: Reward = 18.0, Epsilon = 0.05943728730059528
# Episode 1000: Reward = 20.0, Epsilon = 0.0592891976841853

# %%
plt.figure(figsize=(16,4))
plt.plot(rewards)
plt.xlabel("Episodes")
plt.ylabel("Reward")
# Out:
# Text(0, 0.5, 'Reward')

# %% [markdown]
# ### Visualization

# %%
# For visualization
from gym.wrappers.monitoring import video_recorder
from IPython.display import HTML
from IPython import display
import glob
import base64, io, os

os.environ['SDL_VIDEODRIVER']='dummy'

# %%
os.makedirs("video", exist_ok=True)

def show_video(env_name):
    mp4list = glob.glob('video/*.mp4')
    if len(mp4list) > 0:
        mp4 = 'video/{}.mp4'.format(env_name)
        video = io.open(mp4, 'r+b').read()
        encoded = base64.b64encode(video)
        display.display(HTML(data='''<video alt="test" autoplay
                loop controls style="height: 400px;">
                <source src="data:video/mp4;base64,{0}" type="video/mp4" />
             </video>'''.format(encoded.decode('ascii'))))
    else:
        print("Could not find video")

def show_video_of_model(env_name):
    vid = video_recorder.VideoRecorder(env, path="video/{}.mp4".format(env_name))
    state = env.reset()
    state = torch.tensor([state], device=device)
    done = False
    for t in range(max_steps):
        vid.capture_frame()
        action = get_action(state)
        next_state, reward, done, info = env.step(action.item())
        next_state = torch.tensor([next_state], device=device)
        # print(f"state: {state}, action: {action.item()}",next_state, reward, done)
        state = next_state
        if done:
            break
    vid.close()
    env.close()

# %%
show_video_of_model("CartPole-v1")
# Out:
# /usr/local/lib/python3.10/dist-packages/gym/wrappers/monitoring/video_recorder.py:78: DeprecationWarning: WARN: Recording ability for environment CartPole-v1 initialized with `render_mode=None` is marked as deprecated and will be removed in the future.
#   logger.deprecation(
# /usr/local/lib/python3.10/dist-packages/gym/wrappers/monitoring/video_recorder.py:101: DeprecationWarning: WARN: <class 'gym.wrappers.monitoring.video_recorder.VideoRecorder'> is marked as deprecated and will be removed in the future.
#   logger.deprecation(
# /usr/local/lib/python3.10/dist-packages/gym/core.py:43: DeprecationWarning: WARN: The argument mode in render method is deprecated; use render_mode during environment initialization instead.
# See here for more information: https://www.gymlibrary.ml/content/api/
#   deprecation(
# /usr/local/lib/python3.10/dist-packages/gym/core.py:43: DeprecationWarning: WARN: The argument mode in render method is deprecated; use render_mode during environment initialization instead.
# See here for more information: https://www.gymlibrary.ml/content/api/
#   deprecation(

# %%
show_video("CartPole-v1")
# Out:
# /usr/local/lib/python3.10/dist-packages/ipykernel/ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)
# <video alt="test" autoplay
#                 loop controls style="height: 400px;">
#                 <source src="data:video/mp4;base64,..." type="video/mp4" />
#              </video>
